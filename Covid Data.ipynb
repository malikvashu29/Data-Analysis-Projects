# %%
import pandas as pd

# %%
df = pd.read_csv("D:/DA/Projects/Portfolio/csv/covid deaths.csv")

# %%
df.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24    40099462          5.0
# 1      AFG      Asia  Afghanistan  2020-02-25    40099462          5.0
# 2      AFG      Asia  Afghanistan  2020-02-26    40099462          5.0
# 3      AFG      Asia  Afghanistan  2020-02-27    40099462          5.0
# 4      AFG      Asia  Afghanistan  2020-02-28    40099462          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
df.replace(r'^\s*$', "NULL", regex=True)
df.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24    40099462          5.0
# 1      AFG      Asia  Afghanistan  2020-02-25    40099462          5.0
# 2      AFG      Asia  Afghanistan  2020-02-26    40099462          5.0
# 3      AFG      Asia  Afghanistan  2020-02-27    40099462          5.0
# 4      AFG      Asia  Afghanistan  2020-02-28    40099462          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
df.to_csv('Covid Deaths upd.csv',index= False, encoding='utf-8')
